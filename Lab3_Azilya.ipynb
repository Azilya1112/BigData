# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import datetime as dt
import csv

# %% [markdown]
# 2.	Построить график произвольной квадратичной функции, масштаб задать произвольно. Сделать настройки подписей осей, заголовка фигуры

# %%
a=1
b=0.6
c=0.007

# %%
x=np.linspace(-10,10,400)
y=a*x**2+b*x+c
plt.figure(figsize=(8,6))
plt.plot(x,y, label=f'{a}x^2+{b}x+{c}');
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График квадратичной функции')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# 3.	Построить график произвольной гармонической функции, масштаб задать произвольно. Сделать настройки подписей осей, заголовка фигуры

# %%
x=np.linspace(0, 2*np.pi, 400)
y1=np.sin(x)
plt.figure(figsize=(8,8))
plt.plot(x,y, label=f'sin(x)');
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График гармонической функции')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# 4.	Вывести графики п.2 и 3 в разные поля при помощи функции subplot()

# %%
x_quadratic = np.linspace(-10, 10, 400)
y_quadratic = a * x_quadratic**2 + b * x_quadratic + c

x_harmonic = np.linspace(0, 2 * np.pi, 400)
y_harmonic = np.sin(x_harmonic)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(x_quadratic, y_quadratic, label=f'{a}x^2 + {b}x + {c}')
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График квадратичной функции')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(x_harmonic, y_harmonic, label='sin(x)')
plt.xlabel('X-ось')
plt.ylabel('Y-ось')
plt.title('График гармонической функции')
plt.grid(True)
plt.legend()

plt.tight_layout()  # Обеспечиваем правильное размещение графиков в области
plt.show()

# %% [markdown]
# 5.	Построить графики п.2 и 3 в одной координатной плоскости, сделать подписи графиков, указать легенду.

# %%
a = 1
b = 2
c = 1

# Создаем массивы данных для графиков
x_quadratic = np.linspace(-2, 2, 400)  # Уменьшаем диапазон по оси X
y_quadratic = a * x_quadratic**2 + b * x_quadratic + c

x_harmonic = np.linspace(0, 2 * np.pi, 400)
y_harmonic = np.sin(2 * x_harmonic)

# Создаем рисунок
plt.figure(figsize=(12, 6))

# График квадратичной функции на оси Y1
plt.plot(x_quadratic, y_quadratic, label=f'{a}x^2 + {b}x + {c}', color='blue')
plt.xlabel('X-ось')
plt.ylabel('Квадратичная функция', color='blue')
plt.grid(True)
plt.legend(loc='upper left')

# Создаем вторую ось Y для синусоиды на той же координатной плоскости
ax2 = plt.gca().twinx()

# График синусоиды на оси Y2
ax2.plot(x_harmonic, y_harmonic, label='sin(2x)', color='red')
ax2.set_ylabel('Синусоида', color='red')
ax2.legend(loc='upper right')

plt.title('Графики квадратичной и гармонической функций (узкий диапазон)')
plt.tight_layout()
plt.show()

# %% [markdown]
# 6.	Построить график функции, заданной параметрически x(t)=cos(3t), y(t)=sin(2t), t принадлежит [0,4pi]

# %%
t=np.linspace(0.4*np.pi, 400)

x=np.cos(3*t)
y=np.sin(2*t)

plt.figure(figsize=(8, 6))
plt.plot(x,t, label='x(t)=cos(3t), y(t)=sin(2t)');
plt.xlabel('X')
plt.ylabel('Y')
plt.title('График параметрической функции')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# 7.	Построить столбиковую диаграмму по данным статистического комитета КР по прожиточному минимуму, представленному в таблице

# %%
years=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
living_wage=[4341.15, 4599.21, 4981.51, 5182.99, 4794.34, 4900.79, 4792.54, 4806.32, 5358.53, 6268.31, 7178.32]

plt.figure(figsize=(10, 6))
plt.bar(years, living_wage, color='skyblue')
plt.xlabel('Годы')
plt.ylabel('Прожиточный минимум')
plt.title('Прожиточный минимум по годам')
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Добавляем сетку на ось Y

plt.show()

# %% [markdown]
# 8.	Построить круговой график по данным п. 7

# %%
years=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
living_wage=[4341.15, 4599.21, 4981.51, 5182.99, 4794.34, 4900.79, 4792.54, 4806.32, 5358.53, 6268.31, 7178.32]

plt.figure(figsize=(8, 8))
plt.pie(living_wage, labels=years, autopct='%1.1f%%', startangle=140, shadow=True)
plt.title('Прожиточный минимум по годам')

plt.show()

# %% [markdown]
# 9.	Построить график произвольной каркасной поверхности.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 5 * np.outer(np.cos(u), np.sin(v))
y = 5 * np.outer(np.sin(u), np.sin(v))
z = 5 * np.outer(np.ones(np.size(u)), np.cos(v))

ax.plot_surface(x, y, z, color='none', edgecolor='b')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Произвольная каркасная поверхность')

plt.show()
